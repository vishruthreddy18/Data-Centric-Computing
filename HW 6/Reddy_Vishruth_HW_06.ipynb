# %% [markdown]
# ## CMPINF 2100: Homework 06
#
# ### Vishruth Reddy
#
# ## Assigned: Tuesday of Week 06 at 11:00PM
#
# ## DUE: Tuesday of Week 07 at 11:59PM
#
# ## Overview
#
# This assignment is open ended similar to the previous assignment. You will work with the SAME three data sets as in Homework 05. You already identified the BASIC and ESSENTIAL information for the variables (columns) in the three data sets. You calculated important summary statistics, and even examined if summary statistics changed based on different grouping variables. The Homework 05 exploration results were displayed within DataFrames and/or text. You printed results to the screen and provided Markdown text to accompany the table-like results.
#
# You will repeat many of the same exploration steps from Homework 05, but this time you will **visually** explore the data! You will graphically display the exploratory results using plots/figures. You will explore **marginal** behavior by focusing on individual variables. Then you will explore **combinations** and **relationships** between 2 variables. The figures associated with studying **relationships** will graphically answer the SPLIT-APPLY-COMBINE related questions from the previous assignment. Certain tasks allow you to choose between Pandas plotting methods and Seaborn functions, while others state you must use Seaborn to create the figures.
#
# The last question requires you to start visually exploring **marginal** behavior associated with one of the final projects of your choosing.
#
# **You must use the 3 data sets provided in Homework 05 Canvas assignment page. You may use the same data you previously downloaded, or redownload the CSV files to the appropriate directory on your computer.**
#
# ## Required tasks for Problem 01 through 03
#
# For each of the 3 assigned data sets you must create plots/figures/charts to explore **marginal** behavior. You must therefore perform the following tasks:
#
# * Create BAR CHARTS to visually show the counts for the number of rows per unique value for NON-NUMERIC columns
#     * You may use Pandas or Seaborn to create the bar charts
# * Create HISTOGRAMS to visually show the DISTRIBUTION of NUMERIC columns
#     * You may use Pandas or Seaborn to create the histogram
# * **IMPORTANT:** You **MUST** visually explore the counts of NUMERIC columns that have less than 20 unique values as if they are NON-NUMERIC columns
# * **IMPORTANT:** After creating BAR CHARTS and HISTOGRAMS answer the following:
#     * Do the categories of the NON-NUMERIC columns have similar counts?
#     * Do the histograms of the NUMERIC columns look roughly like bell curves?
#
# For each of the 3 assigned data sets you must create plots/figures/charts to explore **combinations** between 2 NON-NUMERIC columns. You must therefore perform the following tasks:
#
# * Create DODGED bar charts to visually show the COUNTS for COMBINATIONS between 2 NON-NUMERIC columns
#     * You **MUST** create the DODGED bar chart using Seaborn
# * Create HEAT MAPS to visually show the COUNTS for COMBINATIONS between 2 NON-NUMERIC columns
#     * You **MUST** create the HEAT MAP using Seaborn
#     * The HEAT MAP **MUST** be annotated with count displayed as TEXT
# * **IMPORTANT:** You **MUST** treat NUMERIC columns that have less than 20 unique values as if they are NON-NUMERIC columns
# * **IMPORTANT:** After creating the DODGED bar charts and HEAT MAPS answer the following:
#     * Are there combinations between the 2 variables NOT present in the data?
#     * Which plot type was it easier to identify combinations that were NOT present?
#
# For each of the 3 assigned data sets you must create plots/figures/charts to explore **relationships** between CATEGORICAL and CONTINUOUS variables. You must therefore explore the relationship between 1 NON-NUMERIC column and 1 NUMERIC column. You must perform the following tasks:
#
# * Create CONDITIONAL KDE plots to show the conditional distribution of the NUMERIC column CONDITIONED ON (or GROUPED BY) the NON-NUMERIC column
#     * You **MUST** create the CONDITIONAL KDE plot using Seaborn with the NON-NUMERIC column associated with the KDE COLOR
#     * You **MUST** remove the SAMPLE SIZE issue with the CONDITIONAL KDE plot
# * Create BOXPLOTS to show if the SUMMARY STATISTICS of the NUMERIC column CHANGE across the CATEGORIES of the NON-NUMERIC column
#     * You **MUST** create the BOXPLOT using Seaborn
# * Create POINT PLOTS to show if the CONDITIONAL MEAN of the NUMERIC columns CHANGE across the CATEGORIES of the NON-NUMERIC column
#     * You **MUST** create the POINT PLOT using Seaborn
# * **IMPORTANT:** You **MUST** treat NUMERIC columns that have less than 20 unique values as if they are NON-NUMERIC columns
# * **IMPORTANT:** After creating the figures you must answer the following:
#     * Does the distributional SHAPE of a NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?
#     * Does the MEDIAN of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?
#     * Does the VARIATION of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?
#     * Are you confident that the MEAN of the NUMERIC column CHANGES across the CATEGORIES of the NON-NUMERIC column?
#
# ### Collaborators
#
# None
# ## Problem 00
#
# You will work with the NumPy, Pandas, matplotlib.pyplot, and Seaborn modules in this assignment.
#
# Import NumPy, Pandas, matplotlib.pyplot, and Seaborn using their commonly accepted aliases.
#
# #### 00) - SOLUTION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Problem 01
#
# Read in the `hw05_prob_01.csv` CSV file and assign it to the `df01` object.
#
# Visually explore the `df01` object following **ALL** required actions listed previously.
#
# You must add more code cells and markdown cells to complete this problem.
#
# #### 01) - SOLUTION

# %%
df01 = pd.read_csv('hw05_prob_01.csv')

# %%
df01
# Out:
#       A   B   C         x
# 0    a1  b0  C1 -6.240387
# 1    a1  b0  C1 -4.860661
# 2    a1  b0  C1 -5.066712
# 3    a1  b0  C1 -5.635156
# 4    a1  b0  C1 -4.893876
# ..   ..  ..  ..       ...
# 125  a2  b1  C2  1.155377
# 126  a2  b1  C2  2.818466
# 127  a2  b1  C2  3.294759
# 128  a2  b1  C2  2.398190
# 129  a2  b1  C2  2.527589
#
# [130 rows x 4 columns]

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       130 non-null    object
#  1   B       130 non-null    object
#  2   C       130 non-null    object
#  3   x       130 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 4.2+ KB

# %%
df01.nunique()
# Out:
# A      2
# B      2
# C      2
# x    130
# dtype: int64

# %%
df01.isna().sum()
# Out:
# A    0
# B    0
# C    0
# x    0
# dtype: int64

# %%
df01.A.value_counts()
# Out:
# a1    68
# a2    62
# Name: A, dtype: int64

# %%
df01.B.value_counts()
# Out:
# b1    78
# b0    52
# Name: B, dtype: int64

# %%
df01.C.value_counts()
# Out:
# C2    72
# C1    58
# Name: C, dtype: int64

# %% [markdown]
# # Marginal Behavior Exploration
# ## Bar Charts for DF01

# %%
sns.catplot(data = df01, x='A', kind='count')

plt.show()

# %%
sns.catplot(data = df01, x='B', kind='count')

plt.show()

# %%
sns.catplot(data = df01, x='C', kind='count')

plt.show()

# %% [markdown]
# ## Histograms for DF01

# %%
sns.displot( data = df01, x='x', kind='hist', kde=True )

plt.show()

# %% [markdown]
# ## Questions
# **Do the categories of the NON-NUMERIC columns have similar counts?**
#
# *No, the categories of the non-numeric columns don't have a similar count.*
#
# **Do the histograms of the NUMERIC columns look roughly like bell curves?**
#
# *Yes, the histogram roughly looks like a bell-curve.*

# %% [markdown]
# # Exploration of Combination between 2 non-numeric columns
# ## Dodged Bar Charts for DF01

# %%
sns.catplot( data = df01, x='A', hue='B', kind='count' )

plt.show()

# %%
sns.catplot( data = df01, x='B', hue='A', kind='count' )

plt.show()

# %%
sns.catplot( data = df01, x='A', hue='C', kind='count' )

plt.show()

# %%
sns.catplot( data = df01, x='C', hue='A', kind='count' )

plt.show()

# %%
sns.catplot( data = df01, x='C', hue='B', kind='count' )

plt.show()

# %%
sns.catplot( data = df01, x='B', hue='C', kind='count' )

plt.show()

# %% [markdown]
# ## Heat Maps for DF01

# %%
fig, ax = plt.subplots()

sns.heatmap( pd.crosstab( df01.A, df01.B ), ax = ax,
             annot=True, annot_kws={'size': 20}, fmt='d')

plt.show()

# %%
fig, ax = plt.subplots()

sns.heatmap( pd.crosstab( df01.A, df01.C ), ax = ax,
             annot=True, annot_kws={'size': 20}, fmt='d')

plt.show()

# %%
fig, ax = plt.subplots()

sns.heatmap( pd.crosstab( df01.C, df01.B ), ax = ax,
             annot=True, annot_kws={'size': 20}, fmt='d')

plt.show()

# %% [markdown]
# ## Questions
# **Are there combinations between the 2 variables NOT present in the data?**
#
# *There are no missing combinations*
#
# **Which plot type was it easier to identify combinations that were NOT present?**
#
# *It is ideally better to find the missing combinations in heat maps due to the numbers being displayed in the box. In this example, there are no missing combinations.*

# %% [markdown]
# # Categorical and Continuous Variables Relationships Exploration
# ## Conditional KDE Plots for DF01

# %%
sns.displot(data = df01, x='x', hue='A',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = df01, x='x', hue='B',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = df01, x='x', hue='C',
            common_norm=False, kind='kde')

plt.show()

# %% [markdown]
# ## Boxplots for DF01

# %%
sns.catplot(data = df01, x='A', y='x', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = df01, x='B', y='x', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = df01, x='C', y='x', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %% [markdown]
# ## Point Plots for DF01

# %%
sns.catplot( data = df01, x='A', y='x', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = df01, x='B', y='x', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = df01, x='C', y='x', kind='point', join=False )

plt.show()

# %% [markdown]
# ## Questions
#
# **Does the distributional SHAPE of a NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *Yes, the shape is different across the categories of the non-numeric column.*
#
# **Does the MEDIAN of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *Yes, the median is different across the categories of the non-numeric column.*
#
# **Does the VARIATION of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *Yes, the variation is different across the categories of the non-numeric column.*
#
# **Are you confident that the MEAN of the NUMERIC column CHANGES across the CATEGORIES of the NON-NUMERIC column?**
#
# *Yes, the mean changes across the categories of the non-numeric column.*

# %% [markdown]
# ## Problem 02
#
# Read in the `hw05_prob_02.csv` CSV file and assign it to the `df02` object.
#
# Visually explore the `df02` object following **ALL** required actions listed previously.
#
# You must add more code cells and markdown cells to complete this problem.
#
# #### 02) - SOLUTION

# %%
df02 = pd.read_csv('hw05_prob_02.csv')

# %%
df02
# Out:
#             x         y    A   G
# 0    0.249430  1.226548  2.0   1
# 1   -1.049282 -1.100737  NaN   1
# 2   -0.147525 -0.679438  NaN   1
# 3    1.053127 -0.475298  NaN   1
# 4    1.242744 -1.060518  2.0   1
# ..        ...       ...  ...  ..
# 363  0.357651 -0.608975  NaN  14
# 364  0.235176  0.415023  NaN  14
# 365  0.283675 -0.981750  2.0  14
# 366  0.929657 -0.546980  2.0  14
# 367 -1.068429  1.795239  2.0  14
#
# [368 rows x 4 columns]

# %%
df02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       368 non-null    float64
#  1   y       352 non-null    float64
#  2   A       347 non-null    float64
#  3   G       368 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 11.6 KB

# %%
df02.nunique()
# Out:
# x    368
# y    352
# A      2
# G     14
# dtype: int64

# %%
df02.isna().sum()
# Out:
# x     0
# y    16
# A    21
# G     0
# dtype: int64

# %% [markdown]
# # Marginal Behavior Exploration
# ## Bar Charts for DF02

# %%
sns.catplot(data = df02, x='A', kind='count')

plt.show()

# %%
sns.catplot(data = df02, x='G', kind='count', aspect=2)

plt.show()

# %% [markdown]
# ## Histograms for DF02

# %%
sns.displot( data = df02, x='x', kind='hist', kde=True )

plt.show()

# %%
sns.displot( data = df02, x='y', kind='hist', kde=True )

plt.show()

# %% [markdown]
# ## Questions
# **Do the categories of the NON-NUMERIC columns have similar counts?**
#
# *No, the categories of the non-numeric columns don't have a similar count.*
#
# **Do the histograms of the NUMERIC columns look roughly like bell curves?**
#
# *Yes, the histograms look like bell-curves.*

# %% [markdown]
# # Exploration of Combination between 2 non-numeric columns
# ## Dodged Bar Charts for DF02

# %%
sns.catplot( data = df02, x='A', hue='G', kind='count' )

plt.show()

# %%
sns.catplot( data = df02, x='G', hue='A', kind='count' )

plt.show()

# %% [markdown]
# ## Heat Map for DF02

# %%
fig, ax = plt.subplots()

sns.heatmap( pd.crosstab( df02.A, df02.G ), ax = ax,
             annot=True, annot_kws={'size': 10}, fmt='d')

plt.show()

# %% [markdown]
# ## Questions
# **Are there combinations between the 2 variables NOT present in the data?**
#
# *Yes, there are a few combinations with missing data as shown with `0s` in the heat map.*
#
# **Which plot type was it easier to identify combinations that were NOT present?**
#
# *It is better to find the missing combinations in heat maps due to the numbers being displayed in the box. In this example, the missing combinations have `0` in the box and the coloring coding is the `darkest` color.*

# %% [markdown]
# # Categorical and Continuous Variables Relationships Exploration
# ## Conditional KDE Plots for DF02

# %%
sns.displot(data = df02, x='x', hue='A',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = df02, x='x', hue='G',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = df02, x='y', hue='A',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = df02, x='y', hue='G',
            common_norm=False, kind='kde')

plt.show()

# %% [markdown]
# ## Boxplots for DF02

# %%
sns.catplot(data = df02, x='A', y='x', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = df02, x='G', y='x', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = df02, x='A', y='y', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = df02, x='G', y='y', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %% [markdown]
# ## Point Plots for DF02

# %%
sns.catplot( data = df02, x='A', y='x', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = df02, x='G', y='x', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = df02, x='A', y='y', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = df02, x='G', y='y', kind='point', join=False )

plt.show()

# %% [markdown]
# ## Questions
#
# **Does the distributional SHAPE of a NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *Yes, the shape is different across the categories of the non-numeric column.*
#
# **Does the MEDIAN of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *No, the median remains similar across the categories of the non-numeric column.*
#
# **Does the VARIATION of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *Yes, the variation is different across the categories of the non-numeric column.*
#
# **Are you confident that the MEAN of the NUMERIC column CHANGES across the CATEGORIES of the NON-NUMERIC column?**
#
# *No, the mean doesn't change much across the categories of the non-numeric column.*

# %% [markdown]
# ## Problem 03
#
# Read in the `hw05_prob_03.csv` CSV file and assign it to the `df03` object.
#
# Visually explore the `df03` object following **ALL** required actions listed previously.
#
# You must add more code cells and markdown cells to complete this problem.
#
# #### 03) - SOLUTION

# %%
df03 = pd.read_csv('hw05_prob_03.csv')

# %%
df03
# Out:
#       obs_id key     value
# 0          1  x1  0.034632
# 1          2  x1  0.523494
# 2          3  x1  1.224766
# 3          4  x1  1.517422
# 4          5  x1  2.432589
# ...      ...  ..       ...
# 1402     197  x7 -8.145633
# 1403     198  x7       NaN
# 1404     199  x7 -8.152787
# 1405     200  x7 -8.063927
# 1406     201  x7       NaN
#
# [1407 rows x 3 columns]

# %%
df03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407 entries, 0 to 1406
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   obs_id  1407 non-null   int64
#  1   key     1407 non-null   object
#  2   value   1379 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.1+ KB

# %%
df03.nunique()
# Out:
# obs_id     201
# key          7
# value     1379
# dtype: int64

# %%
df03.isna().sum()
# Out:
# obs_id     0
# key        0
# value     28
# dtype: int64

# %%
df03.key.value_counts()
# Out:
# x1    201
# x2    201
# x3    201
# x4    201
# x5    201
# x6    201
# x7    201
# Name: key, dtype: int64

# %% [markdown]
# ## Bar Charts for DF03

# %%
sns.catplot(data = df03, x='key', kind='count')

plt.show()

# %% [markdown]
# ## Histograms for DF03

# %%
sns.displot( data = df03, x='obs_id', kind='hist', kde=True )

plt.show()

# %%
sns.displot( data = df03, x='value', kind='hist', kde=True )

plt.show()

# %% [markdown]
# ## Questions
# **Do the categories of the NON-NUMERIC columns have similar counts?**
#
# *Yes, the `key` category has a similar count.*
#
# **Do the histograms of the NUMERIC columns look roughly like bell curves?**
#
# *No, the `obs_id` histogram doesn't look like a bell-curve.*
#
# *Yes, the `value` histogram looks like a bell-curve.*

# %% [markdown]
# # Exploration of Combination between 2 non-numeric columns
# ## Dodged Bar Charts for DF03

# %%
sns.catplot( data = df03, x='key', kind='count' )

plt.show()

# %% [markdown]
# ***Combining 2 non-numeric columns isn't possible for `df03` as there is only 1 non-numeric value. Hence, creating a dodged bar chart didn't yield a different graph as compared to a normal bar chart***

# %% [markdown]
# ## Heat Maps for DF03

# %%
fig, ax = plt.subplots()

# sns.heatmap( pd.crosstab( df03.key ), ax = ax,
#              annot=True, annot_kws={'size': 20}, fmt='d')

sns.heatmap( pd.crosstab(df03.key, columns='count'), ax = ax,
             annot=True, annot_kws={'size': 15}, fmt='d')

plt.show()

# %% [markdown]
# ## Questions
# **Are there combinations between the 2 variables NOT present in the data?**
#
# *There are no missing combinations as there is only 1 non-numeric column.*
#
# **Which plot type was it easier to identify combinations that were NOT present?**
#
# *It is ideally better to find the missing combinations in heat maps due to the numbers being displayed in the box. In this example, there are no missing combinations.*

# %% [markdown]
# # Categorical and Continuous Variables Relationships Exploration
# ## Conditional KDE Plots for DF03

# %%
sns.displot(data = df03, x='obs_id', hue='key',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = df03, x='value', hue='key',
            common_norm=False, kind='kde')

plt.show()

# %% [markdown]
# ## Boxplots for DF03

# %%
sns.catplot(data = df03, x='key', y='obs_id', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = df03, x='key', y='value', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %% [markdown]
# ## Point Plots for DF03

# %%
sns.catplot( data = df03, x='key', y='obs_id', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = df03, x='key', y='value', kind='point', join=False )

plt.show()

# %% [markdown]
# ## Questions
#
# **Does the distributional SHAPE of a NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *No, the shape is the same across `key` and `obs_id`.*
#
# *Yes, the shape is different across `key` and `value`.*
#
# **Does the MEDIAN of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *No, the median is the same across `key` and `obs_id`.*
#
# *Yes, the median is different across `key` and `value`.*
#
# **Does the VARIATION of the NUMERIC column appear to be different across the CATEGORIES of the NON-NUMERIC column?**
#
# *No, the variation is the same across `key` and `obs_id`.*
#
# *Yes, the variation is different across `key` and `value`.*
#
# **Are you confident that the MEAN of the NUMERIC column CHANGES across the CATEGORIES of the NON-NUMERIC column?**
#
# *No, the mean doesn't change across `key` and `obs_id`.*
#
# *Yes, the mean changes across `key` and `value`.*

# %% [markdown]
# ## Problem 04
#
# You must download the data associated with one of the Final Projects from the Canvas site. Save the file(s) in the same directory as this Jupyter notebook.
#
# Read in the data associated with one of the Final Projects. You must start to visually explore the variables in the Project data. However, you do NOT need to explore ALL variables in this assignment.
#
# You **MUST** visually explore the **marginal** behavior of at least 6 variables. You must use the plot type appropriate for the data type and number of unique values for each variable.
#
# #### 04) - SOLUTION

# %% [markdown]
# ## Customer Churn: Sponsored by PPG

# %%
dfcc = pd.read_csv('ppg_churn_data.csv')

# %%
dfcc
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       KS             128  area_code_415                 no             yes
# 1       OH             107  area_code_415                 no             yes
# 2       NJ             137  area_code_415                 no              no
# 3       OH              84  area_code_408                yes              no
# 4       OK              75  area_code_415                yes              no
# ...    ...             ...            ...                ...             ...
# 4995    HI              50  area_code_408                 no             yes
# 4996    WV             152  area_code_415                 no              no
# 4997    DC              61  area_code_415                 no              no
# 4998    DC             109  area_code_510                 no              no
# 4999    VT              86  area_code_415                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 4995                     40              235.7              127
# 4996                      0              184.2               90
# 4997                      0              140.6               89
# 4998                      0              188.8               67
# 4999                     34              129.4              102
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 4995             40.07              223.0              126             18.96
# 4996             31.31              256.8               73             21.83
# 4997             23.90              172.8              128             14.69
# 4998             32.10              171.7               92             14.59
# 4999             22.00              267.1              104             22.70
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 4995                297.5                116               13.39
# 4996                213.6                113                9.61
# 4997                212.4                 97                9.56
# 4998                224.4                 89               10.10
# 4999                154.8                100                6.97
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 4995                 9.9                 5               2.67
# 4996                14.7                 2               3.97
# 4997                13.6                 4               3.67
# 4998                 8.5                 6               2.30
# 4999                 9.3                16               2.51
#
#       number_customer_service_calls churn
# 0                                 1    no
# 1                                 1    no
# 2                                 0    no
# 3                                 2    no
# 4                                 3    no
# ...                             ...   ...
# 4995                              2    no
# 4996                              3   yes
# 4997                              1    no
# 4998                              0    no
# 4999                              0    no
#
# [5000 rows x 20 columns]

# %%
dfcc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          5000 non-null   object
#  1   account_length                 5000 non-null   int64
#  2   area_code                      5000 non-null   object
#  3   international_plan             5000 non-null   object
#  4   voice_mail_plan                5000 non-null   object
#  5   number_vmail_messages          5000 non-null   int64
#  6   total_day_minutes              5000 non-null   float64
#  7   total_day_calls                5000 non-null   int64
#  8   total_day_charge               5000 non-null   float64
#  9   total_eve_minutes              5000 non-null   float64
#  10  total_eve_calls                5000 non-null   int64
#  11  total_eve_charge               5000 non-null   float64
#  12  total_night_minutes            5000 non-null   float64
#  13  total_night_calls              5000 non-null   int64
#  14  total_night_charge             5000 non-null   float64
#  15  total_intl_minutes             5000 non-null   float64
#  16  total_intl_calls               5000 non-null   int64
#  17  total_intl_charge              5000 non-null   float64
#  18  number_customer_service_calls  5000 non-null   int64
#  19  churn                          5000 non-null   object
# dtypes: float64(8), int64(7), object(5)
# memory usage: 781.4+ KB

# %%
dfcc.dtypes.value_counts()
# Out:
# float64    8
# int64      7
# object     5
# dtype: int64

# %%
dfcc.shape
# Out:
# (5000, 20)

# %%
dfcc.nunique()
# Out:
# state                              51
# account_length                    218
# area_code                           3
# international_plan                  2
# voice_mail_plan                     2
# number_vmail_messages              48
# total_day_minutes                1961
# total_day_calls                   123
# total_day_charge                 1961
# total_eve_minutes                1879
# total_eve_calls                   126
# total_eve_charge                 1659
# total_night_minutes              1853
# total_night_calls                 131
# total_night_charge               1028
# total_intl_minutes                170
# total_intl_calls                   21
# total_intl_charge                 170
# number_customer_service_calls      10
# churn                               2
# dtype: int64

# %%
dfcc.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
dfcc.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count      5000.00000            5000.000000        5000.000000
# mean        100.25860               7.755200         180.288900
# std          39.69456              13.546393          53.894699
# min           1.00000               0.000000           0.000000
# 25%          73.00000               0.000000         143.700000
# 50%         100.00000               0.000000         180.100000
# 75%         127.00000              17.000000         216.200000
# max         243.00000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      5000.000000       5000.000000        5000.000000      5000.000000
# mean        100.029400         30.649668         200.636560       100.191000
# std          19.831197          9.162069          50.551309        19.826496
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.375000        87.000000
# 50%         100.000000         30.620000         201.000000       100.000000
# 75%         113.000000         36.750000         234.100000       114.000000
# max         165.000000         59.760000         363.700000       170.000000
#
#        total_eve_charge  total_night_minutes  total_night_calls  \
# count       5000.000000          5000.000000        5000.000000
# mean          17.054322           200.391620          99.919200
# std            4.296843            50.527789          19.958686
# min            0.000000             0.000000           0.000000
# 25%           14.140000           166.900000          87.000000
# 50%           17.090000           200.400000         100.000000
# 75%           19.900000           234.700000         113.000000
# max           30.910000           395.000000         175.000000
#
#        total_night_charge  total_intl_minutes  total_intl_calls  \
# count         5000.000000         5000.000000       5000.000000
# mean             9.017732           10.261780          4.435200
# std              2.273763            2.761396          2.456788
# min              0.000000            0.000000          0.000000
# 25%              7.510000            8.500000          3.000000
# 50%              9.020000           10.300000          4.000000
# 75%             10.560000           12.000000          6.000000
# max             17.770000           20.000000         20.000000
#
#        total_intl_charge  number_customer_service_calls
# count        5000.000000                    5000.000000
# mean            2.771196                       1.570400
# std             0.745514                       1.306363
# min             0.000000                       0.000000
# 25%             2.300000                       1.000000
# 50%             2.780000                       1.000000
# 75%             3.240000                       2.000000
# max             5.400000                       9.000000

# %%
dfcc.describe(include='object')
# Out:
#        state      area_code international_plan voice_mail_plan churn
# count   5000           5000               5000            5000  5000
# unique    51              3                  2               2     2
# top       WV  area_code_415                 no              no    no
# freq     158           2495               4527            3677  4293

# %% [markdown]
# ***After looking at the summary statistics, we are considering `number_customer_service_calls` and `total_intl_calls` as categorical values due to their low count in unique values.***

# %% [markdown]
# ***The variables we are considering are as follows:***
#
# **Categorical Values:** *`state`, `area_code`, `international_plan`, `total_intl_calls` and `churn`*
#
# **Numeric Values:** *`total_day_minutes`, `total_night_minutes`, `total_intl_charge` and `total_intl_minutes`*

# %% [markdown]
# ## Bar Charts

# %%
sns.catplot( data = dfcc, y='state', kind='count', height=12 )

plt.show()

# %%
sns.catplot( data = dfcc, y='area_code', kind='count', height=4 )

plt.show()

# %%
sns.catplot( data = dfcc, y='churn', kind='count', height=4 )

plt.show()

# %%
sns.catplot( data = dfcc, y='total_intl_calls', kind='count', height=12 )

plt.show()

# %%
sns.catplot( data = dfcc, y='international_plan', kind='count', height=4 )

plt.show()

# %% [markdown]
# ## Histograms

# %%
sns.displot(data = dfcc, x='total_day_minutes', kind='hist', kde=True)

plt.show()

# %%
sns.displot(data = dfcc, x='total_night_minutes', kind='hist', kde=True)

plt.show()

# %%
sns.displot(data = dfcc, x='total_intl_charge', kind='hist', kde=True)

plt.show()

# %%
sns.displot(data = dfcc, x='total_intl_minutes', kind='hist', kde=True)

plt.show()

# %% [markdown]
# ## Dodged Bar Charts

# %%
sns.catplot( data = dfcc, x='state', hue='area_code', kind='count', height=12, aspect=1 )

plt.show()

# %%
sns.catplot( data = dfcc, x='state', hue='international_plan', kind='count', height=12, aspect=1 )

plt.show()

# %%
sns.catplot( data = dfcc, x='state', hue='churn', kind='count', height=15, aspect=1 )

plt.show()

# %% [markdown]
# ## Heat Maps

# %%
fig, ax = plt.subplots(figsize=(3,15))

sns.heatmap( pd.crosstab( dfcc.state, dfcc.area_code ), ax = ax,
             annot=True, annot_kws={'size': 8}, fmt='d')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,15))

sns.heatmap( pd.crosstab( dfcc.state, dfcc.international_plan ), ax = ax,
             annot=True, annot_kws={'size': 8}, fmt='d')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,15))

sns.heatmap( pd.crosstab( dfcc.state, dfcc.churn ), ax = ax,
             annot=True, annot_kws={'size': 8}, fmt='d')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.heatmap( pd.crosstab( dfcc.international_plan, dfcc.area_code ), ax = ax,
             annot=True, annot_kws={'size': 20}, fmt='d')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.heatmap( pd.crosstab( dfcc.churn, dfcc.area_code ), ax = ax,
             annot=True, annot_kws={'size': 20}, fmt='d')

plt.show()

# %% [markdown]
# ## KDE

# %%
sns.displot(data = dfcc, x='total_intl_minutes', hue='state',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = dfcc, x='total_intl_minutes', hue='area_code',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = dfcc, x='total_day_minutes', hue='state',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = dfcc, x='total_night_minutes', hue='state',
            common_norm=False, kind='kde')

plt.show()

# %%
sns.displot(data = dfcc, x='total_intl_minutes', hue='churn',
            common_norm=False, kind='kde')

plt.show()

# %% [markdown]
# ## Boxplots

# %%
sns.catplot(data = dfcc, x='area_code', y='total_day_minutes', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = dfcc, x='churn', y='total_day_minutes', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = dfcc, x='area_code', y='total_night_minutes', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = dfcc, x='churn', y='total_night_minutes', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = dfcc, x='total_intl_calls', y='total_day_minutes', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %%
sns.catplot(data = dfcc, x='total_intl_calls', y='total_night_minutes', kind='box',
            showmeans=True,
            meanprops={'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'})

plt.show()

# %% [markdown]
# ## Point Plots

# %%
sns.catplot( data = dfcc, x='churn', y='total_night_minutes', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = dfcc, x='churn', y='total_day_minutes', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = dfcc, x='area_code', y='total_day_minutes', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = dfcc, x='area_code', y='total_night_minutes', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = dfcc, x='total_intl_calls', y='total_day_minutes', kind='point', join=False )

plt.show()

# %%
sns.catplot( data = dfcc, x='total_intl_calls', y='total_night_minutes', kind='point', join=False )

plt.show()
